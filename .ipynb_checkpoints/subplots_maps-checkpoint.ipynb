# %%
import pandas as pd


merged_df = pd.read_csv('merged_data_w_coord.csv')

# %%
merged_df
# Out:
#        Unnamed: 0     Country of Giftor                    Institution Name  \
# 0               0           Afghanistan               Ball State University
# 1             654                Brazil               Ball State University
# 2            3097                 China               Ball State University
# 3            3098                 China               Ball State University
# 4            3099                 China               Ball State University
# ...           ...                   ...                                 ...
# 21047       18516           Switzerland  Hult International Business School
# 21048       19790                Taiwan               Mount Holyoke College
# 21049       20120              Thailand              Saint Louis University
# 21050       20121              Thailand              Saint Louis University
# 21051       20680  United Arab Emirates            Colorado School of Mines
#
#           ID    OPEID          City State Foreign Gift Received Date  \
# 0        830   178600        Muncie    IN                 2013-08-28
# 1       6491   178600        Muncie    IN                 2014-08-18
# 2        201   178600        Muncie    IN                 2014-08-18
# 3        367   178600        Muncie    IN                 2017-08-21
# 4        965   178600        Muncie    IN                 2018-01-08
# ...      ...      ...           ...   ...                        ...
# 21047     64  4143200     Cambridge    MA                 2012-10-01
# 21048   9615   219200  South Hadley    MA                 2013-08-27
# 21049  12123   250600   Saint Louis    MO                 2013-05-09
# 21050  12133   250600   Saint Louis    MO                 2013-05-09
# 21051   5728   134800        Golden    CO                 2012-06-06
#
#        Foreign Gift Amount      Gift Type  ... Functioning of government  \
# 0                  3000000       Contract  ...                      0.64
# 1                   264041       Contract  ...                      5.36
# 2                  7184164       Contract  ...                      4.29
# 3                  4218639       Contract  ...                      4.29
# 4                  1782825       Contract  ...                      4.29
# ...                    ...            ...  ...                       ...
# 21047             21532410       Contract  ...                      9.29
# 21048               300000  Monetary Gift  ...                      8.21
# 21049               250000  Monetary Gift  ...                      5.36
# 21050               250000  Monetary Gift  ...                      5.36
# 21051              3500000       Contract  ...                      3.93
#
#       Political participation  Political culture  Civil liberties  \
# 0                        3.89               2.50             3.82
# 1                        6.11               5.00             8.24
# 2                        3.33               2.50             1.18
# 3                        3.33               2.50             1.18
# 4                        3.33               2.50             1.18
# ...                       ...                ...              ...
# 21047                    7.78               9.38             9.12
# 21048                    6.11               5.63             9.12
# 21049                    6.11               6.25             6.47
# 21050                    6.11               6.25             6.47
# 21051                    2.22               5.00             2.65
#
#             Regime type                      Region  Country Latitude  \
# 0         Authoritarian          Asia & Australasia         33.768006
# 1      Flawed democracy               Latin America        -10.333333
# 2         Authoritarian          Asia & Australasia         35.000074
# 3         Authoritarian          Asia & Australasia         35.000074
# 4         Authoritarian          Asia & Australasia         35.000074
# ...                 ...                         ...               ...
# 21047    Full democracy              Western Europe         46.798562
# 21048  Flawed democracy          Asia & Australasia         23.598298
# 21049  Flawed democracy          Asia & Australasia         14.897192
# 21050  Flawed democracy          Asia & Australasia         14.897192
# 21051     Authoritarian  Middle East & North Africa         24.000249
#
#        Country Longitude  School Latitude School Longitude
# 0              66.238514        38.958058       -95.247750
# 1             -53.200000        38.958058       -95.247750
# 2             104.999927        38.958058       -95.247750
# 3             104.999927        38.958058       -95.247750
# 4             104.999927        38.958058       -95.247750
# ...                  ...              ...              ...
# 21047           8.231974        42.369985       -71.070640
# 21048         120.835363        38.635284       -90.231677
# 21049         100.832730        33.414809      -112.010831
# 21050         100.832730        33.414809      -112.010831
# 21051          53.999483        34.364612       -89.539635
#
# [21052 rows x 25 columns]

# %%
import matplotlib.pyplot as plt
import mplleaflet
from IPython.display import IFrame    


x = merged_df['School Longitude'].unique().tolist()
y = merged_df['School Latitude'].unique().tolist()
n = merged_df['Institution Name'].unique().tolist()

fig = plt.figure(figsize=(8,8))
plt.scatter(x,
            y,
            color='blue', 
            alpha=0.7, 
            s=100,
           )
mplleaflet.save_html(fileobj='school_map.html')
IFrame('school_map.html', width=800, height=650)
# Out:
#         <iframe
#             width="800"
#             height="650"
#             src="school_map.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
x = merged_df['Country Longitude'].unique().tolist()
y = merged_df['Country Latitude'].unique().tolist()
n = merged_df['Country of Giftor'].unique().tolist()

fig = plt.figure(figsize=(8,8))
plt.scatter(x,
            y,
            color='blue', 
            alpha=0.7, 
            s=100,
           )
mplleaflet.save_html(fileobj='country_map.html')
IFrame('country_map.html', width=550, height=450)
# Out:
#         <iframe
#             width="550"
#             height="450"
#             src="country_map.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import geopandas
import geoplot
import mapclassify


world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
counts = merged_df.groupby(['Country to merge on']).count()['ID']

world['name'].sort_values()
# Out:
# 103    Afghanistan
# 125        Albania
# 82         Algeria
# 74          Angola
# 159     Antarctica
#           ...
# 2        W. Sahara
# 157          Yemen
# 70          Zambia
# 48        Zimbabwe
# 73        eSwatini
# Name: name, Length: 177, dtype: object

# %%
merged_world = pd.merge(world, counts.reset_index(), left_on='name', right_on='Country to merge on', how='outer')
merged_world[merged_world['name'].isnull()]
# Out:
#      pop_est continent name iso_a3  gdp_md_est geometry  \
# 177      NaN       NaN  NaN    NaN         NaN     None
# 178      NaN       NaN  NaN    NaN         NaN     None
# 179      NaN       NaN  NaN    NaN         NaN     None
# 180      NaN       NaN  NaN    NaN         NaN     None
# 181      NaN       NaN  NaN    NaN         NaN     None
# 182      NaN       NaN  NaN    NaN         NaN     None
# 183      NaN       NaN  NaN    NaN         NaN     None
# 184      NaN       NaN  NaN    NaN         NaN     None
# 185      NaN       NaN  NaN    NaN         NaN     None
# 186      NaN       NaN  NaN    NaN         NaN     None
#
#         Country to merge on     ID
# 177                 Bahrain   11.0
# 178  Bosnia and Herzegovina    4.0
# 179          Czech Republic   10.0
# 180      Dominican Republic    3.0
# 181               Hong Kong  806.0
# 182                   Malta    5.0
# 183               Mauritius    2.0
# 184               Not Rated  264.0
# 185               Singapore  300.0
# 186           United States   27.0

# %%
name_dict = {'Bosnia and Herz.': 'Bosnia and Herzegovina',
             'Czechia': 'Czech Republic',
             'Dominican Rep.': 'Dominican Republic',
             'Mauritania': 'Mauritius',
             'United States of America': 'United States'}

# %%
new_world = world.replace(name_dict)

# %%
new_merged_world = pd.merge(new_world, counts.reset_index(), left_on='name', right_on='Country to merge on', how='outer')
new_merged_world
# Out:
#          pop_est      continent           name iso_a3  gdp_md_est  \
# 0       920938.0        Oceania           Fiji    FJI      8374.0
# 1     53950935.0         Africa       Tanzania    TZA    150600.0
# 2       603253.0         Africa      W. Sahara    ESH       906.5
# 3     35623680.0  North America         Canada    CAN   1674000.0
# 4    326625791.0  North America  United States    USA  18560000.0
# ..           ...            ...            ...    ...         ...
# 177          NaN            NaN            NaN    NaN         NaN
# 178          NaN            NaN            NaN    NaN         NaN
# 179          NaN            NaN            NaN    NaN         NaN
# 180          NaN            NaN            NaN    NaN         NaN
# 181          NaN            NaN            NaN    NaN         NaN
#
#                                               geometry Country to merge on  \
# 0    MULTIPOLYGON (((180.00000 -16.06713, 180.00000...                 NaN
# 1    POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...            Tanzania
# 2    POLYGON ((-8.66559 27.65643, -8.66512 27.58948...                 NaN
# 3    MULTIPOLYGON (((-122.84000 49.00000, -122.9742...              Canada
# 4    MULTIPOLYGON (((-122.84000 49.00000, -120.0000...       United States
# ..                                                 ...                 ...
# 177                                               None             Bahrain
# 178                                               None           Hong Kong
# 179                                               None               Malta
# 180                                               None           Not Rated
# 181                                               None           Singapore
#
#          ID
# 0       NaN
# 1      31.0
# 2       NaN
# 3    2076.0
# 4      27.0
# ..      ...
# 177    11.0
# 178   806.0
# 179     5.0
# 180   264.0
# 181   300.0
#
# [182 rows x 8 columns]

# %%
hacked_world = new_merged_world[~new_merged_world['pop_est'].isna()].fillna(0)
hacked_world['ID'].hist()

# %%
scheme = mapclassify.JenksCaspall(hacked_world['ID'], k=5)
geoplot.choropleth(hacked_world,
                   hue=hacked_world['ID'],
                   scheme=scheme,
                   cmap='Blues',
                   figsize=(10, 8),
                   legend=True)

# %%
shapes_df = hacked_world[['Country to merge on', 'geometry', 'ID']].rename({'ID': 'Country donation counts'}, axis=1)

# %%
pd.merge(merged_df, shapes_df, left_on='Country to merge on', right_on='Country to merge on', how='left')
# Out:
#        Unnamed: 0     Country of Giftor                    Institution Name  \
# 0               0           Afghanistan               Ball State University
# 1             654                Brazil               Ball State University
# 2            3097                 China               Ball State University
# 3            3098                 China               Ball State University
# 4            3099                 China               Ball State University
# ...           ...                   ...                                 ...
# 21047       18516           Switzerland  Hult International Business School
# 21048       19790                Taiwan               Mount Holyoke College
# 21049       20120              Thailand              Saint Louis University
# 21050       20121              Thailand              Saint Louis University
# 21051       20680  United Arab Emirates            Colorado School of Mines
#
#           ID    OPEID          City State Foreign Gift Received Date  \
# 0        830   178600        Muncie    IN                 2013-08-28
# 1       6491   178600        Muncie    IN                 2014-08-18
# 2        201   178600        Muncie    IN                 2014-08-18
# 3        367   178600        Muncie    IN                 2017-08-21
# 4        965   178600        Muncie    IN                 2018-01-08
# ...      ...      ...           ...   ...                        ...
# 21047     64  4143200     Cambridge    MA                 2012-10-01
# 21048   9615   219200  South Hadley    MA                 2013-08-27
# 21049  12123   250600   Saint Louis    MO                 2013-05-09
# 21050  12133   250600   Saint Louis    MO                 2013-05-09
# 21051   5728   134800        Golden    CO                 2012-06-06
#
#        Foreign Gift Amount      Gift Type  ... Political culture  \
# 0                  3000000       Contract  ...              2.50
# 1                   264041       Contract  ...              5.00
# 2                  7184164       Contract  ...              2.50
# 3                  4218639       Contract  ...              2.50
# 4                  1782825       Contract  ...              2.50
# ...                    ...            ...  ...               ...
# 21047             21532410       Contract  ...              9.38
# 21048               300000  Monetary Gift  ...              5.63
# 21049               250000  Monetary Gift  ...              6.25
# 21050               250000  Monetary Gift  ...              6.25
# 21051              3500000       Contract  ...              5.00
#
#       Civil liberties       Regime type                      Region  \
# 0                3.82     Authoritarian          Asia & Australasia
# 1                8.24  Flawed democracy               Latin America
# 2                1.18     Authoritarian          Asia & Australasia
# 3                1.18     Authoritarian          Asia & Australasia
# 4                1.18     Authoritarian          Asia & Australasia
# ...               ...               ...                         ...
# 21047            9.12    Full democracy              Western Europe
# 21048            9.12  Flawed democracy          Asia & Australasia
# 21049            6.47  Flawed democracy          Asia & Australasia
# 21050            6.47  Flawed democracy          Asia & Australasia
# 21051            2.65     Authoritarian  Middle East & North Africa
#
#        Country Latitude  Country Longitude  School Latitude  School Longitude  \
# 0             33.768006          66.238514        38.958058        -95.247750
# 1            -10.333333         -53.200000        38.958058        -95.247750
# 2             35.000074         104.999927        38.958058        -95.247750
# 3             35.000074         104.999927        38.958058        -95.247750
# 4             35.000074         104.999927        38.958058        -95.247750
# ...                 ...                ...              ...               ...
# 21047         46.798562           8.231974        42.369985        -71.070640
# 21048         23.598298         120.835363        38.635284        -90.231677
# 21049         14.897192         100.832730        33.414809       -112.010831
# 21050         14.897192         100.832730        33.414809       -112.010831
# 21051         24.000249          53.999483        34.364612        -89.539635
#
#                                                 geometry  \
# 0      POLYGON ((66.51861 37.36278, 67.07578 37.35614...
# 1      POLYGON ((-53.37366 -33.76838, -53.65054 -33.2...
# 2      MULTIPOLYGON (((109.47521 18.19770, 108.65521 ...
# 3      MULTIPOLYGON (((109.47521 18.19770, 108.65521 ...
# 4      MULTIPOLYGON (((109.47521 18.19770, 108.65521 ...
# ...                                                  ...
# 21047  POLYGON ((9.59423 47.52506, 9.63293 47.34760, ...
# 21048  POLYGON ((121.77782 24.39427, 121.17563 22.790...
# 21049  POLYGON ((105.21878 14.27321, 104.28142 14.416...
# 21050  POLYGON ((105.21878 14.27321, 104.28142 14.416...
# 21051  POLYGON ((51.57952 24.24550, 51.75744 24.29407...
#
#       Country donation counts
# 0                        15.0
# 1                       192.0
# 2                      1597.0
# 3                      1597.0
# 4                      1597.0
# ...                       ...
# 21047                  1303.0
# 21048                   386.0
# 21049                    86.0
# 21050                    86.0
# 21051                   177.0
#
# [21052 rows x 27 columns]
